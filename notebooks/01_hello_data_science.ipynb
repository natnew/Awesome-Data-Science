# %% [markdown]
# <a href="https://colab.research.google.com/github/natnew/Awesome-Data-Science/blob/main/notebooks/01_hello_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Hello World: Data Science Edition 🌍
#
# Welcome to your first interactive Data Science notebook! In this guide, we will:
# 1. Load a dataset using `pandas`.
# 2. Visualize the data using `matplotlib`.
# 3. Train a simple model (optional teaser).
#
# No installation required—this runs entirely in the cloud!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load a built-in dataset
df = sns.load_dataset('iris')

# 2. Inspect the first few rows
print("Here are the first 5 rows of our dataset:")
display(df.head())

# %% [markdown]
# ### Visualizing the Data
# Data science is about storytelling. Let's see how different species compare using a pairplot.

# %%
# 3. Create a visualization
plt.figure(figsize=(10, 6))
sns.pairplot(df, hue='species', markers=["o", "s", "D"])
plt.show()

# %% [markdown]
# ### Conclusion
# Congratulations! You've just ran your first data science workflow.
#
# **Next Steps:**
# - Try changing the dataset to `'penguins'`.
# - Explore other visualizations like `sns.boxplot`.
